# %%
import pandas as pd

# %%
real_estate=pd.read_csv('Real_Estate.csv')

# %%
real_estate.head()
# Out:
#              Transaction date  House age  Distance to the nearest MRT station  \
# 0  2012-09-02 16:42:30.519336       13.3                            4082.0150
# 1  2012-09-04 22:52:29.919544       35.5                             274.0144
# 2  2012-09-05 01:10:52.349449        1.1                            1978.6710
# 3  2012-09-05 13:26:01.189083       22.2                            1055.0670
# 4  2012-09-06 08:29:47.910523        8.5                             967.4000
#
#    Number of convenience stores   Latitude   Longitude  \
# 0                             8  25.007059  121.561694
# 1                             2  25.012148  121.546990
# 2                            10  25.003850  121.528336
# 3                             5  24.962887  121.482178
# 4                             6  25.011037  121.479946
#
#    House price of unit area
# 0                  6.488673
# 1                 24.970725
# 2                 26.694267
# 3                 38.091638
# 4                 21.654710

# %%
print(real_estate.isnull().sum())
# Out:
# Transaction date                       0
# House age                              0
# Distance to the nearest MRT station    0
# Number of convenience stores           0
# Latitude                               0
# Longitude                              0
# House price of unit area               0
# dtype: int64

# %%
print(real_estate.describe())
# Out:
#         House age  Distance to the nearest MRT station  \
# count  414.000000                           414.000000
# mean    18.405072                          1064.468233
# std     11.757670                          1196.749385
# min      0.000000                            23.382840
# 25%      9.900000                           289.324800
# 50%     16.450000                           506.114400
# 75%     30.375000                          1454.279000
# max     42.700000                          6306.153000
#
#        Number of convenience stores    Latitude   Longitude  \
# count                    414.000000  414.000000  414.000000
# mean                       4.265700   24.973605  121.520268
# std                        2.880498    0.024178    0.026989
# min                        0.000000   24.932075  121.473888
# 25%                        2.000000   24.952422  121.496866
# 50%                        5.000000   24.974353  121.520912
# 75%                        6.750000   24.994947  121.544676
# max                       10.000000   25.014578  121.565321
#
#        House price of unit area
# count                414.000000
# mean                  29.102149
# std                   15.750935
# min                    0.000000
# 25%                   18.422493
# 50%                   30.394070
# 75%                   40.615184
# max                   65.571716

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
features=['Distance to the nearest MRT station','Number of convenience stores','Latitude','Longitude']
target='House price of unit area'

# %%
features
# Out:
# ['Distance to the nearest MRT station',
#  'Number of convenience stores',
#  'Latitude',
#  'Longitude']

# %%
x=real_estate[features]
y=real_estate[target]

# %%
x.head()
# Out:
#    Distance to the nearest MRT station  Number of convenience stores  \
# 0                            4082.0150                             8
# 1                             274.0144                             2
# 2                            1978.6710                            10
# 3                            1055.0670                             5
# 4                             967.4000                             6
#
#     Latitude   Longitude
# 0  25.007059  121.561694
# 1  25.012148  121.546990
# 2  25.003850  121.528336
# 3  24.962887  121.482178
# 4  25.011037  121.479946

# %%
y.head()
# Out:
# 0     6.488673
# 1    24.970725
# 2    26.694267
# 3    38.091638
# 4    21.654710
# Name: House price of unit area, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#      Distance to the nearest MRT station  Number of convenience stores  \
# 302                            1867.2330                             8
# 20                              330.0854                             6
# 303                             815.9314                             7
# 142                             377.7956                             4
# 14                              185.4296                             5
# ..                                   ...                           ...
# 323                             350.8515                             3
# 192                            2147.3760                             3
# 117                             512.5487                             5
# 47                             1013.3410                             6
# 172                             292.9978                            10
#
#       Latitude   Longitude
# 302  24.974157  121.489834
# 20   24.960582  121.497347
# 303  24.932509  121.507956
# 142  24.971820  121.483007
# 14   24.937197  121.545059
# ..         ...         ...
# 323  24.991400  121.520064
# 192  24.933732  121.564450
# 117  24.954015  121.549075
# 47   24.934676  121.494472
# 172  24.932805  121.510373
#
# [331 rows x 4 columns]

# %%
y_train
# Out:
# 302    46.625530
# 20     47.355551
# 303    36.495212
# 142    28.956939
# 14     40.255333
#          ...
# 323    39.529670
# 192     0.365176
# 117    21.711905
# 47     13.060738
# 172    65.571716
# Name: House price of unit area, Length: 331, dtype: float64

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([ -2.74595146,  30.97112553,  39.52455494,  29.49414334,
#         36.35010461,  33.48511576,  35.35772564,  29.77046615,
#         18.66011874,  30.03542183,  45.90368803,  21.08391261,
#         35.40102919,  28.19058977,  29.54432529,  32.3752172 ,
#         29.10017476,  27.49240818,  44.78061241,  36.28915019,
#         33.91165595,  41.23084799,  19.44645741,  29.20602899,
#         42.40247776,  36.51346787,  22.88680136,  31.58935623,
#         26.62776536,  38.53933962,  26.96473639,  31.33408857,
#         32.40976987,  41.36151334,  45.18710927,  26.58054153,
#         18.62534651,  41.22333529,  34.79340621,  17.73125501,
#         38.61644496,  36.76592103,  40.96643846,  30.03099309,
#         19.22839044,  35.90995273,  38.8014434 ,  37.11454718,
#         18.60984194,   4.80506982,  39.41871101,  33.25217877,
#         33.17067551,  35.24625144,  26.14411111,  40.24659002,
#         31.34969861,  24.88548358,  42.10134356,  30.32513881,
#         32.56302229,  39.81520867,  29.51363123,  26.50749407,
#         28.17438846,  28.07777828,  14.127238  ,  34.60552834,
#         16.84988241,  35.20425198,  39.30460219,  36.77654553,
#         36.24470203,   9.81638355,  36.32276794,  34.49110835,
#         32.40451274,  26.95464685,  26.62541491,  29.93681294,
#         35.07526009,  35.10505363, -15.99561469])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,5))
plt.scatter(y_test,y_pred,alpha=0.5)
plt.plot([y_test.min(),y_test.max()],[y_test.min(),y_test.max()])
plt.xlabel('actual')
plt.ylabel('predicted')
plt.title('actual vs predicted')
plt.show()
